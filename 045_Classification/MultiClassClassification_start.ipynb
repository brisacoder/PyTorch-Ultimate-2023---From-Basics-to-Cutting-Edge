# %%
# data import
iris = load_iris()
X = iris.data
y = iris.target

# %%
# hyper parameters
# NUM_FEATURES = ...
# HIDDEN = ...
# NUM_CLASSES = ...

# %%
# loss function
criterion = nn.CrossEntropyLoss()
